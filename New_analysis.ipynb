# %% [markdown]
# # lnc mRNA Filtering
#
# One of the main features of transcription is **alternative splicing (AS)**. This process allows one gene to produce differents mRNA products by modulating the AS machinery. Each unique alternative transcript is called an **isoform**, every gene can have one or more isoforms with different characteristics. Different isoforms can code for different proteins, commonly alternative isoforms have **premature stop codons (PTCs)** that funnel the transcripts to the degradation machinery (**NMD**). In this work we propose a **new function for mRNAs**, some isoforms never reach the ribosomes for translation and also are not degraded, making them an stable molecule that acummulates in the cell. We belive this isoforms have a role as lnc-mRNAs, mainly in the nucleus. This script is intended to filter out isoforms taking into account all the above mentiones characteristics, leaving us with a small group of lnc-mRNA isoforms for further studies.
#
# lnc RNAs will be filtered by two main features: Stable RNAs (not degraded) and not translated. Four datasets are used in this script:
# - Polyribosomes: https://doi.org/10.1111/tpj.12502
# - NMD deficient(Cicloheximide and upf1 & upf3 mutants): https://doi.org/10.1105/tpc.113.115485
# - Own ONT data (Total, Nuclear, Citoplasmatic)
# - Own illumina data (Total, Nuclear, Citoplasmatic)
#
# **Objectives:**
# - Define a universe of isoforms (total isoforms present in the model studied)
# - Remove the isoforms that are being translated (polyribosomes)
# - Remove the isoforms that are being degraded (NMD deficient)
#     - To achieve this, isoforms that increase their presence on NMD deficient samples, are considered NMD sensitive
# - Keep the nuclear isoforms (and discard the citoplasmatic)
# - Asses light/Dark changes.
# - Quantify the proportion in nucleus/citoplasm of this isoforms
#
# *For this analisys I used a modified version of "AtRTD2_QUASI", called "AtRTD2.1_QUASI". This version was done by filtering out low expressed isoforms from 155 datasets quantified by SALMON using the "AtRTD2_QUASI" transcriptome (this datasets include illumina and ONT data).*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import concatenate_files_exclude

# %%
import empias

# %% [markdown]
# ## Load data

# %%
file_dir = "/home/lucas-elytron/Documents/paper_doct/lnc_mrna/mapping/salmon/AtRTDv2_1_QUASI"
transcriptome = pd.read_parquet("/home/lucas-elytron/Documents/paper_doct/lnc_mrna/mapping/reference/mod_refs/AtRTDv2_1_QUASI.LS.parquet")

# %%
# Load all Illumina quantification data (NMD conditions + polyribosome)
# Excludes the ONT_data subfolder
illumina_data, illumina_files = concatenate_files_exclude(file_dir, transcriptome, "ONT_data")
print(f"Loaded {illumina_files} Illumina sample(s)")

grouped_illu = illumina_data.groupby("df_name")
illu_groups  = {name: grp for name, grp in grouped_illu}

# --- NMD conditions, 2 biological replicates each ---
nmd_map = {
    "NMD_CHX_quant":          ("CHX",      "rep1"),
    "NMD_MOCK_quant":         ("MOCK",     "rep1"),
    "NMD_UPF1_quant":         ("UPF1",     "rep1"),
    "NMD_UPF1UPF3_quant":    ("UPF1UPF3", "rep1"),
    "NMD_UPF3_quant":         ("UPF3",     "rep1"),
    "NMD_WT_quant":           ("WT",       "rep1"),
    "NMD_CHX_R2_quant":       ("CHX",      "rep2"),
    "NMD_MOCK_R2_quant":      ("MOCK",     "rep2"),
    "NMD_UPF1_R2_quant":      ("UPF1",     "rep2"),
    "NMD_UPF1UPF3_R2_quant": ("UPF1UPF3", "rep2"),
    "NMD_UPF3_R2_quant":      ("UPF3",     "rep2"),
    "NMD_WT_R2_quant":        ("WT",       "rep2"),
}
available = {k: v for k, v in nmd_map.items() if k in illu_groups}
nmd_df = pd.concat(
    {v: illu_groups[k]["TPM"] for k, v in available.items()},
    axis=1
)
nmd_df.columns = pd.MultiIndex.from_tuples(
    list(available.values()), names=["condition", "replicate"]
)

# --- Polyribosome replicates (ERR377676-78, DOI: 10.1111/tpj.12502) ---
polyribo_map = {"ERR377676": "rep1", "ERR377677": "rep2", "ERR377678": "rep3"}
polyribo_df = pd.concat(
    {label: illu_groups[key]["TPM"]
     for key, label in polyribo_map.items() if key in illu_groups},
    axis=1
)

conds = list(nmd_df.columns.get_level_values("condition").unique())
print(f"NMD conditions (both reps): {conds}")
print(f"NMD df shape:               {nmd_df.shape}  (expected 54095 x 12)")
print(f"Polyribosome reps loaded:   {list(polyribo_df.columns)}")
nmd_df.loc[["AT3G61860"], :]
# Out:
# Loaded 15 Illumina sample(s)
# NMD conditions (both reps): ['CHX', 'MOCK', 'UPF1', 'UPF1UPF3', 'UPF3', 'WT']
# NMD df shape:               (54095, 12)  (expected 54095 x 12)
# Polyribosome reps loaded:   ['rep1', 'rep2', 'rep3']
# condition                      CHX       MOCK       UPF1   UPF1UPF3  \
# replicate                     rep1       rep1       rep1       rep1
# gene      isoform
# AT3G61860 AT3G61860_ID2   7.526846  21.839957  35.591510  31.148346
#           AT3G61860_P1    3.061675  15.876204   7.757980  11.322559
#           AT3G61860_s1    0.090624   1.398329   5.838495   3.684376
#           AT3G61860_s2   12.375660  11.541558   5.688878  47.315357
#
# condition                     UPF3         WT        CHX       MOCK  \
# replicate                     rep1       rep1       rep2       rep2
# gene      isoform
# AT3G61860 AT3G61860_ID2  32.378725  23.847747   5.389627  11.673262
#           AT3G61860_P1    6.432160   8.399215  13.243918  50.335368
# ...

# %%
# Load ONT subcellular fractionation data
# Excludes PRJNA176940 (Illumina NMD) but still finds polyribosome ERR dirs — filter below
ONT_data, ONT_files = concatenate_files_exclude(file_dir, transcriptome, "PRJNA176940")
print(f"Loaded {ONT_files} file(s) from ONT + polyribosome dirs")

grouped_ont = ONT_data.groupby('df_name')
ont_groups  = {name: grp for name, grp in grouped_ont}

# Keep only ONT barcode directories (exclude polyribosome ERR accessions)
ont_names = sorted(
    [x for x in ont_groups.keys() if not x.startswith('ERR')],
    key=lambda x: int(x.split('barcode')[-1])
)
print(f"ONT barcodes found: {len(ont_names)}")

# Barcode → condition mapping (3 replicates per condition)
# barcode 01-03: Nuclear Light | 04-06: Nuclear Dark
# barcode 07-09: Cytoplasmic Light | 10-12: Cytoplasmic Dark
ont_keys = [
    ("Nuc L", "rep1"), ("Nuc L", "rep2"), ("Nuc L", "rep3"),
    ("Nuc D", "rep1"), ("Nuc D", "rep2"), ("Nuc D", "rep3"),
    ("Cit L", "rep1"), ("Cit L", "rep2"), ("Cit L", "rep3"),
    ("Cit D", "rep1"), ("Cit D", "rep2"), ("Cit D", "rep3"),
]
assert len(ont_names) == len(ont_keys), \
    f"Expected 12 ONT barcodes, found {len(ont_names)}: {ont_names}"

ONT_nuc_cito = pd.concat(
    [ont_groups[x]['TPM'] for x in ont_names],
    axis=1, keys=pd.MultiIndex.from_tuples(ont_keys, names=["condition", "sample"])
)
print(f"ONT data shape: {ONT_nuc_cito.shape}")
ONT_nuc_cito.loc[["AT3G61860"], :]
# Out:
# Loaded 15 file(s) from ONT + polyribosome dirs
# ONT barcodes found: 12
# ONT data shape: (54095, 12)
# condition                     Nuc L                               Nuc D  \
# sample                         rep1        rep2        rep3        rep1
# gene      isoform
# AT3G61860 AT3G61860_ID2  136.466411  135.012686  311.250844  557.108229
#           AT3G61860_P1    43.749715   52.408766   53.185616   43.947466
#           AT3G61860_s1    19.868876   26.468734    9.250141   51.987760
#           AT3G61860_s2     0.000000    0.000000    0.000000    0.000000
#
# condition                                            Cit L              \
# sample                         rep2        rep3       rep1        rep2
# gene      isoform
# AT3G61860 AT3G61860_ID2  550.914695  558.654675   2.707569    0.000000
#           AT3G61860_P1    31.514748   51.051770  74.128790  104.001051
#           AT3G61860_s1    61.765164   52.703543   0.000000    2.460159
# ...

# %% [markdown]
# ---
# ## Filter 1 — Polyribosome-bound (translated) isoforms
#
# Isoforms actively being translated are present in the polyribosome fraction.
# Criterion: **TPM > 1 in ALL 3 replicates** (ERR377676/77/78, DOI: 10.1111/tpj.12502).
# This conservative criterion ensures only robustly translated isoforms are removed.
# These are excluded from the candidate pool.

# %%
TPM_THRESHOLD = 1.0

# Original criterion: TPM > 1 in ALL 3 polyribosome replicates (conservative)
translated_mask = (polyribo_df > TPM_THRESHOLD).all(axis=1)
translated_isoforms = set(
    polyribo_df[translated_mask].index.get_level_values('isoform')
)
print(f"Translated isoforms (polyribosome TPM > {TPM_THRESHOLD} in ALL 3 reps): {len(translated_isoforms)}")

# Spot check
print(f"AT3G61860 isoforms in polyribosome set: {[i for i in translated_isoforms if i.startswith("AT3G61860")]}")
print(f"AT3G02300 isoforms in polyribosome set: {[i for i in translated_isoforms if i.startswith("AT3G02300")]}")
# Out:
# Translated isoforms (polyribosome TPM > 1.0 in ALL 3 reps): 17764
# AT3G61860 isoforms in polyribosome set: ['AT3G61860_P1']
# AT3G02300 isoforms in polyribosome set: ['AT3G02300_P1']

# %% [markdown]
# ---
# ## Filter 2 — NMD-sensitive (degraded) isoforms
#
# NMD-sensitive isoforms **accumulate** when the NMD pathway is inhibited.
# Pre-computed EmpiAS p-values are used for 4 comparisons (from original analysis):
#
# 1. **CHX vs MOCK** (pval_table_Chx_Mock.csv)
# 2. **UPF1 vs WT** (pval_table_upf1_wt.csv)
# 3. **UPF3 vs WT** (pval_table_upf3_wt.csv)
# 4. **UPF1+UPF3 vs WT** (pval_table_upf1upf3_wt.csv)
#
# Criterion: **p < 0.05** with **logFC > 0** in at least one comparison.
# Union = NMD-sensitive isoforms to be excluded from candidates.

# %%
# Use pre-computed NMD EmpiAS p-values from original analysis
nmd_files = {
    "CHX vs MOCK":    "./data/pval_table_Chx_Mock.csv",
    "UPF1 vs WT":     "./data/pval_table_upf1_wt.csv",
    "UPF3 vs WT":     "./data/pval_table_upf3_wt.csv",
    "UPF1UPF3 vs WT": "./data/pval_table_upf1upf3_wt.csv",
}

P_NMD = 0.05
nmd_isoforms = set()
for label, fpath in nmd_files.items():
    df = pd.read_csv(fpath)
    sig = set(df[(df["pvalues"] < P_NMD) & (df["logFC"] > 0)]["isoform"].dropna())
    nmd_isoforms |= sig
    print(f"NMD-sensitive ({label:>15s}): {len(sig):>6,}")

print(f"Union of NMD-sensitive isoforms:      {len(nmd_isoforms):>6,}")
print(f"AT3G02300_ID3 NMD-sensitive: {'AT3G02300_ID3' in nmd_isoforms}")
# Out:
# NMD-sensitive (    CHX vs MOCK):  2,440
# NMD-sensitive (     UPF1 vs WT):    880
# NMD-sensitive (     UPF3 vs WT):    320
# NMD-sensitive ( UPF1UPF3 vs WT):  3,067
# Union of NMD-sensitive isoforms:       5,315
# AT3G02300_ID3 NMD-sensitive: False

# %% [markdown]
# ---
# ## Filter 3 — Nuclear-enriched isoforms (EmpiAS)
#
# ONT subcellular fractionation provides direct evidence of nuclear retention.
# The nuclear enrichment criterion uses pre-computed EmpiAS p-values from the
# ONT dataset comparing **Nuclear Light vs all other conditions** (cytoplasmic + dark):
#
#
# This is the most stringent comparison: an isoform must be enriched in the nuclear
# fraction relative to ALL other conditions combined, not just cytoplasmic.
#
# Criterion: **p < 0.05** with **logFC > 0** (higher in Nuclear Light vs others).

# %%
# Use pre-computed ONT nuclear EmpiAS results (Nuclear Light vs Other)
# "Other" = Cytoplasmic + Dark (stricter than Light vs Cytoplasmic only)
pval_ont_nuc = pd.read_csv("./data/pval_ONT_nuc_L_O.csv")
print(f"Loaded ONT nuclear p-values: {pval_ont_nuc.shape[0]:,} isoforms")
pval_ont_nuc.head()
# Out:
# Loaded ONT nuclear p-values: 54,095 isoforms
#         gene       isoform     logFC  tpm_mean   pvalues
# 0  AT1G01010   AT1G01010.1  1.036005      -inf  0.002498
# 1  AT1G01020  AT1G01020_P1 -0.020143   6.84575  1.000000
# 2  AT1G01020  AT1G01020_P2       NaN   6.84575  0.000000
# 3  AT1G01020  AT1G01020_P3  0.210351   6.84575  1.000000
# 4  AT1G01020  AT1G01020_P4       NaN   6.84575  0.000000

# %%
P_CUTOFF = 0.05

nuclear_isoforms = set(
    pval_ont_nuc[
        (pval_ont_nuc["pvalues"] < P_CUTOFF) & (pval_ont_nuc["logFC"] > 0)
    ]["isoform"]
)

print(f"Nuclear-enriched (ONT Nuc L vs Other, p<{P_CUTOFF}): {len(nuclear_isoforms):>6,}")
# Out:
# Nuclear-enriched (ONT Nuc L vs Other, p<0.05):  4,347

# %% [markdown]
# ---
# ## Final candidates — lncRNA-mRNA isoforms
#
# Candidates must satisfy **all three criteria**:
#
# | Criterion | Direction |
# |---|---|
# | NOT in polyribosomes | Not translated |
# | NOT NMD-sensitive | Not degraded |
# | Nuclear-enriched (ONT) | Retained in nucleus |
#
# Additionally, a gene must have **≥2 expressed isoforms** — confirming a genuine alternative splicing event.

# %%
# Universe: isoforms expressed in the ONT data (mean TPM > 0)
expressed_in_ont = set(
    ONT_nuc_cito[ONT_nuc_cito.mean(axis=1) > 0]
    .index.get_level_values('isoform')
)

# Step-by-step filter
step1 = nuclear_isoforms - translated_isoforms          # nuclear AND not translated
step2 = step1 - nmd_isoforms                             # + not NMD-sensitive

# Require ≥2 expressed isoforms per gene
genes_multi = (
    ONT_nuc_cito[ONT_nuc_cito.index.get_level_values('isoform').isin(expressed_in_ont)]
    .groupby('gene')
    .filter(lambda x: len(x) >= 2)
    .index.get_level_values('isoform')
    .unique()
)
multi_isoform_set = set(genes_multi)

candidates = step2 & multi_isoform_set

print(f"Universe (expressed in ONT):          {len(expressed_in_ont):>6,}")
print(f"Translated (polyribosome):            {len(translated_isoforms):>6,}")
print(f"NMD-sensitive:                        {len(nmd_isoforms):>6,}")
print(f"Nuclear-enriched:                     {len(nuclear_isoforms):>6,}")
print(f"─" * 46)
print(f"Nuclear & not translated:             {len(step1):>6,}")
print(f"Nuclear & not translated & not NMD:   {len(step2):>6,}")
print(f"Final candidates (multi-isoform gene):{len(candidates):>6,}")
# Out:
# Universe (expressed in ONT):          49,511
# Translated (polyribosome):            17,764
# NMD-sensitive:                         5,315
# Nuclear-enriched:                      4,347
# ──────────────────────────────────────────────
# Nuclear & not translated:              2,564
# Nuclear & not translated & not NMD:    2,254
# Final candidates (multi-isoform gene): 2,016

# %%
# Save ranked by mean nuclear TPM
nuc_mean = ONT_nuc_cito.loc[:, "Nuc L"].mean(axis=1)
candidates_df = (
    nuc_mean[nuc_mean.index.get_level_values('isoform').isin(candidates)]
    .sort_values(ascending=False)
    .reset_index()
    .rename(columns={0: 'mean_nuc_L_tpm'})
)
candidates_df.to_csv("./data/candidates_lncRNA_mRNA.csv", index=False)
print(f"Saved {len(candidates_df)} candidates to data/candidates_lncRNA_mRNA.csv")

# ── Validation ──────────────────────────────────────────────────────────────
print("\n── Validation ──────────────────────────────────────────────────────")
# AT3G61860 (At-RS31): expected positive control
rs31 = candidates_df[candidates_df['gene'] == 'AT3G61860']
print(f"At-RS31 (AT3G61860) in candidates: {len(rs31)} isoform(s)")
if not rs31.empty:
    display(rs31)

# AT3G02300 (At-RCC1): query
rcc1 = candidates_df[candidates_df['gene'] == 'AT3G02300']
print(f"At-RCC1 (AT3G02300) in candidates: {len(rcc1)} isoform(s)")
if not rcc1.empty:
    display(rcc1)
# Out:
# Saved 2016 candidates to data/candidates_lncRNA_mRNA.csv
#
# ── Validation ──────────────────────────────────────────────────────
# At-RS31 (AT3G61860) in candidates: 2 isoform(s)
#           gene        isoform  mean_nuc_L_tpm
# 4    AT3G61860  AT3G61860_ID2      194.243314
# 256  AT3G61860   AT3G61860_s1       18.529250
# At-RCC1 (AT3G02300) in candidates: 1 isoform(s)
#           gene        isoform  mean_nuc_L_tpm
# 106  AT3G02300  AT3G02300_ID3       35.344459

# %% [markdown]
# ---
# ## Figures

# %%
import os
from matplotlib_venn import venn3

os.makedirs("Figures", exist_ok=True)

fig, ax = plt.subplots(figsize=(8, 6))
venn3(
    subsets=[translated_isoforms, nmd_isoforms, nuclear_isoforms],
    set_labels=('Polyribosome\n(Translated)', 'NMD-sensitive\n(Degraded)', 'Nuclear-enriched'),
    ax=ax
)
ax.set_title(
    'Isoform universe partitioning\n'
    f'lncRNA-mRNA candidates = nuclear-only region (n={len(candidates):,})',
    fontsize=11
)
plt.tight_layout()
plt.savefig('Figures/venn_candidate_filter.png', dpi=300, bbox_inches='tight')
plt.show()
print("Saved Figures/venn_candidate_filter.png")
# Out:
# Saved Figures/venn_candidate_filter.png

# %%
nuc_L_mean = ONT_nuc_cito.loc[:, "Nuc L"].mean(axis=1)
expr_cands  = nuc_L_mean[nuc_L_mean.index.get_level_values('isoform').isin(candidates)]
expr_cands  = expr_cands[expr_cands > 0]

fig, ax = plt.subplots(figsize=(8, 4))
np.log2(expr_cands + 1).plot(kind='hist', bins=50, ax=ax,
                              color='steelblue', edgecolor='white')
ax.set_xlabel('log₂(TPM + 1) — Nuclear Light fraction')
ax.set_ylabel('Number of isoforms')
ax.set_title(f'Expression of {len(candidates):,} lncRNA-mRNA candidates (Nuclear Light)')
plt.tight_layout()
plt.savefig('Figures/candidates_expression_distribution.png', dpi=300, bbox_inches='tight')
plt.show()
print("Saved Figures/candidates_expression_distribution.png")
# Out:
# Saved Figures/candidates_expression_distribution.png

# %% [markdown]
# ### Figure 1a — Candidate filtering funnel

# %%
# Figure 1a — Candidate filtering funnel
not_transl     = expressed_in_ont - translated_isoforms
not_transl_nmd = not_transl - nmd_isoforms
nuclear_pass   = not_transl_nmd & nuclear_isoforms
final_pass     = nuclear_pass & multi_isoform_set   # == candidates

steps  = ["Universe\n(ONT expressed)",
          "Not translated\n(polyribosome filter)",
          "Not NMD-sensitive\n(NMD filter)",
          "Nuclear-enriched\n(ONT fractionation)",
          "Multi-isoform gene\n(final candidates)"]
counts = [len(expressed_in_ont), len(not_transl), len(not_transl_nmd),
          len(nuclear_pass), len(final_pass)]

fig, ax = plt.subplots(figsize=(10, 5))
colors = ["#4878CF", "#6ACC65", "#D65F5F", "#B47CC7", "#C4AD66"]
bars = ax.bar(steps, counts, color=colors, edgecolor='white', linewidth=0.8)

for bar, n in zip(bars, counts):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 400,
            f"{n:,}", ha='center', va='bottom', fontsize=9, fontweight='bold')

ax.set_ylabel("Number of isoforms", fontsize=11)
ax.set_title("lncRNA-mRNA candidate filtering pipeline", fontsize=13, fontweight='bold')
ax.set_ylim(0, max(counts) * 1.12)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("Figures/filter_funnel.png", dpi=300)
plt.show()
print(f"Saved Figures/filter_funnel.png  |  Final: {len(final_pass):,} candidates")
# Out:
# Saved Figures/filter_funnel.png  |  Final: 2,016 candidates

# %% [markdown]
# ### Figure 1b — ONT nuclear vs cytoplasmic isoform populations

# %%
# Figure 1b — ONT isoform populations: nuclear vs cytoplasmic
import matplotlib.patches as mpatches

cond_order = ["Nuc L", "Nuc D", "Cit L", "Cit D"]
cond_colors = {"Nuc L": "#4878CF", "Nuc D": "#2B4C8C",
               "Cit L": "#D65F5F", "Cit D": "#8C2B2B"}

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
for ax, label, title in zip(axes,
                             [["Nuc L", "Cit L"], ["Nuc D", "Cit D"]],
                             ["Light condition", "Dark condition"]):
    data = []
    xlabels = []
    for cond in label:
        vals = ONT_nuc_cito.loc[:, cond].mean(axis=1)
        vals = np.log2(vals[vals > 0] + 1)
        data.append(vals)
        xlabels.append(cond)

    bp = ax.violinplot(data, positions=[1, 2], showmedians=True,
                       showextrema=False)
    for body, cond in zip(bp['bodies'], label):
        body.set_facecolor(cond_colors[cond])
        body.set_alpha(0.7)
    bp['cmedians'].set_color('black')
    bp['cmedians'].set_linewidth(1.5)

    ax.set_xticks([1, 2])
    ax.set_xticklabels(xlabels, fontsize=11)
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.spines[['top', 'right']].set_visible(False)

axes[0].set_ylabel("log₂(TPM + 1)", fontsize=11)
fig.suptitle("ONT isoform expression: Nuclear vs Cytoplasmic fractions", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig("Figures/ONT_nuclear_vs_cytoplasmic.png", dpi=300)
plt.show()
print("Saved Figures/ONT_nuclear_vs_cytoplasmic.png")
# Out:
# Saved Figures/ONT_nuclear_vs_cytoplasmic.png

# %% [markdown]
# ### Figure 1c — Filter category overlap (Venn)

# %%
# Figure 1c — Overlap of NMD-sensitive, translated and nuclear isoforms
from matplotlib_venn import venn3

fig, ax = plt.subplots(figsize=(7, 6))
v = venn3(
    subsets=(nmd_isoforms, translated_isoforms, nuclear_isoforms),
    set_labels=("NMD-sensitive\n(5,315)", "Translated\n(17,764)", "Nuclear-enriched\n(4,347)"),
    ax=ax
)
if v:
    for text in v.set_labels:
        if text:
            text.set_fontsize(10)
    for text in v.subset_labels:
        if text:
            text.set_fontsize(9)

ax.set_title("Overlap of isoform filter categories\n(from 49,511 ONT-expressed isoforms)",
             fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig("Figures/filter_categories_venn.png", dpi=300)
plt.show()
print("Saved Figures/filter_categories_venn.png")
# Out:
# Saved Figures/filter_categories_venn.png

# %% [markdown]
# ### Figure 1d — At-RS31 isoform expression

# %%
# Figure 1d — At-RS31 (AT3G61860) isoform expression across ONT conditions
gene_id = "AT3G61860"
gene_data = ONT_nuc_cito.loc[[gene_id]]

conds = ["Nuc L", "Nuc D", "Cit L", "Cit D"]
isoforms = gene_data.index.get_level_values("isoform").unique().tolist()

means = {iso: [] for iso in isoforms}
sems  = {iso: [] for iso in isoforms}
for iso in isoforms:
    for cond in conds:
        vals = gene_data.loc[(gene_id, iso), cond].values.astype(float)
        means[iso].append(vals.mean())
        sems[iso].append(vals.std() / np.sqrt(len(vals)))

iso_colors = {"AT3G61860_ID2": "#4878CF",   # candidate (nuclear)
              "AT3G61860_s1":  "#6ACC65",    # candidate (nuclear)
              "AT3G61860_P1":  "#D65F5F",    # translated
              "AT3G61860_s2":  "#AAAAAA"}    # other

x = np.arange(len(conds))
width = 0.2
fig, ax = plt.subplots(figsize=(10, 5))
for k, iso in enumerate(isoforms):
    color = iso_colors.get(iso, "#AAAAAA")
    ax.bar(x + k * width, means[iso], width, yerr=sems[iso],
           label=iso, color=color, capsize=3, edgecolor='white', linewidth=0.5)

ax.set_xticks(x + width * (len(isoforms) - 1) / 2)
ax.set_xticklabels(conds, fontsize=11)
ax.set_ylabel("Mean TPM (ONT, 3 replicates)", fontsize=11)
ax.set_title(f"At-RS31 ({gene_id}) — isoform expression by subcellular fraction",
             fontsize=12, fontweight='bold')
ax.legend(fontsize=9, framealpha=0.8)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("Figures/AtRS31_isoform_expression.png", dpi=300)
plt.show()
print("Saved Figures/AtRS31_isoform_expression.png")
# Out:
# Saved Figures/AtRS31_isoform_expression.png

# %% [markdown]
# ### Figure 1e — At-RCC1 isoform expression

# %%
# Figure 1e — At-RCC1 (AT3G02300) isoform expression across ONT conditions
gene_id = "AT3G02300"
gene_data = ONT_nuc_cito.loc[[gene_id]]

conds = ["Nuc L", "Nuc D", "Cit L", "Cit D"]
isoforms = gene_data.index.get_level_values("isoform").unique().tolist()

means = {iso: [] for iso in isoforms}
sems  = {iso: [] for iso in isoforms}
for iso in isoforms:
    for cond in conds:
        vals = gene_data.loc[(gene_id, iso), cond].values.astype(float)
        means[iso].append(vals.mean())
        sems[iso].append(vals.std() / np.sqrt(len(vals)))

iso_colors = {"AT3G02300_ID3": "#4878CF",   # candidate (nuclear)
              "AT3G02300_P1":  "#D65F5F",    # translated
              "AT3G02300_ID1": "#AAAAAA",
              "AT3G02300_ID4": "#C4AD66"}

x = np.arange(len(conds))
width = 0.2
fig, ax = plt.subplots(figsize=(10, 5))
for k, iso in enumerate(isoforms):
    color = iso_colors.get(iso, "#AAAAAA")
    ax.bar(x + k * width, means[iso], width, yerr=sems[iso],
           label=iso, color=color, capsize=3, edgecolor='white', linewidth=0.5)

ax.set_xticks(x + width * (len(isoforms) - 1) / 2)
ax.set_xticklabels(conds, fontsize=11)
ax.set_ylabel("Mean TPM (ONT, 3 replicates)", fontsize=11)
ax.set_title(f"At-RCC1 ({gene_id}) — isoform expression by subcellular fraction",
             fontsize=12, fontweight='bold')
ax.legend(fontsize=9, framealpha=0.8)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("Figures/AtRCC1_isoform_expression.png", dpi=300)
plt.show()
print("Saved Figures/AtRCC1_isoform_expression.png")
# Out:
# Saved Figures/AtRCC1_isoform_expression.png

# %% [markdown]
# ### Figure 1f — Multi-isoform gene distribution

# %%
# Figure 1f — Multi-isoform distribution among the 2,016 candidates
isos_per_gene = (
    candidates_df.groupby('gene')['isoform'].count()
    .value_counts()
    .sort_index()
)
total_genes = len(candidates_df['gene'].unique())

fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(isos_per_gene.index.astype(str), isos_per_gene.values,
       color="#4878CF", edgecolor='white', linewidth=0.8)
for x, v in zip(isos_per_gene.index, isos_per_gene.values):
    ax.text(str(x), v + 2, str(v), ha='center', va='bottom', fontsize=9)

ax.set_xlabel("Candidate isoforms per gene", fontsize=11)
ax.set_ylabel("Number of genes", fontsize=11)
ax.set_title(f"Isoform multiplicity in 2,016 candidates ({total_genes:,} unique genes)",
             fontsize=12, fontweight='bold')
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("Figures/candidates_isoforms_per_gene.png", dpi=300)
plt.show()
print(f"Saved Figures/candidates_isoforms_per_gene.png | {total_genes} unique genes")
# Out:
# 2026-03-25 11:53:13,663 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-03-25 11:53:13,664 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-03-25 11:53:13,688 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-03-25 11:53:13,689 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
print("── At-RS31 (AT3G61860) spot check ──────")
display(ONT_nuc_cito.loc[["AT3G61860"], :])
print("p-values (ONT Nuc L vs Other):")
display(pval_ont_nuc[pval_ont_nuc["gene"] == "AT3G61860"].sort_values("pvalues"))
cands = pd.read_csv("./data/candidates_lncRNA_mRNA.csv")
print("At-RS31 (AT3G61860):", "AT3G61860" in cands.gene.values)
print("At-RCC1 (AT3G02300):", "AT3G02300" in cands.gene.values)
# Out:
# ── At-RS31 (AT3G61860) spot check ──────
# condition                     Nuc L                               Nuc D  \
# sample                         rep1        rep2        rep3        rep1
# gene      isoform
# AT3G61860 AT3G61860_ID2  136.466411  135.012686  311.250844  557.108229
#           AT3G61860_P1    43.749715   52.408766   53.185616   43.947466
#           AT3G61860_s1    19.868876   26.468734    9.250141   51.987760
#           AT3G61860_s2     0.000000    0.000000    0.000000    0.000000
#
# condition                                            Cit L              \
# sample                         rep2        rep3       rep1        rep2
# gene      isoform
# AT3G61860 AT3G61860_ID2  550.914695  558.654675   2.707569    0.000000
#           AT3G61860_P1    31.514748   51.051770  74.128790  104.001051
#           AT3G61860_s1    61.765164   52.703543   0.000000    2.460159
#           AT3G61860_s2     1.485313    0.000000   0.000000    0.000000
#
# ...
